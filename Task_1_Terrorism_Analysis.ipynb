# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/CVIP/blob/main/Task_1_Terrorism_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project - Terrorism Analysis**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - CodersCave**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/CVIP/blob/main/Task_1_Terrorism_Analysis.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/1pCGzscpi3x-Ya9EULjzkubIvfhbslkN8)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# The goal of this project is to perform Exploratory Data Analysis (EDA) on the terrorism dataset to extract meaningful insights and patterns. By analyzing the dataset, we aim to uncover trends, identify high-risk regions, understand attack characteristics, and potentially reveal factors that contribute to terrorist activities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Access the Drive from Colab, to access the file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/folders/Terrorism Dataset.csv", encoding = 'latin-1')
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.rename(columns = {'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'}, inplace = True)

# %%
# Choosing the important factors to go ahead with
terrorism = df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# ...

# %%
# Checking the null values in the data
terrorism.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
sns.heatmap(terrorism.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
plt.show()

# %%
Country_names = terrorism.Country.value_counts().index

# %%
Country_val = terrorism.Country.value_counts().values

# %%
plt.pie(Country_val[:3], labels = Country_names[:3], autopct = '%1.2f%%')
plt.axis('equal')
plt.title('Top 3 Countries', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Country with the hightest number of attacks is
#
# 1. Iran
# 2. Afghanisthan
# 3. Pakistan

# %%
City_names = terrorism.city.value_counts().index
City_val = terrorism.city.value_counts().values

# %%
plt.pie(City_val[:3], labels = City_names[:3], autopct = '%1.2f%%')
# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Cities', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Cities with the hightest number of attacks is
#
# 1. Baghdad
# 2. Karachi

# %%
print("City with the most attacks:", terrorism['city'].value_counts().index[1])
# Out:
# City with the most attacks: Baghdad

# %%
Region_names = terrorism.Region.value_counts().index
Region_val = terrorism.Region.value_counts().values

# %%
plt.pie(Region_val[:3], labels = Region_names[:3], autopct = '%1.2f%%')
# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Region', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Regions with the hightest number of attacks is
#
# 1. Middle East & North Africa
# 2. South Asia
# 3. South America

# %%
Year_names = terrorism.Year.value_counts().index
Year_val = terrorism.Year.value_counts().values

# %%
plt.pie(Year_val[:3], labels = Year_names[:3], autopct = '%1.2f%%')
# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Year of Attack', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Year with the hightest number of attacks is
#
# 1. 2014
# 2. 2015
# 3. 2016

# %%
Month_names = terrorism.Month.value_counts().index
Month_val = terrorism.Month.value_counts().values

# %%
plt.pie(Month_val[:3], labels = Month_names[:3], autopct = '%1.2f%%')
# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Month of Attack', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Month with the highest number of attacks is
#
# 5. May
# 7. July
# 8. August

# %%
Group_names = terrorism.Group.value_counts().index
Group_val = terrorism.Group.value_counts().values

# %%
plt.pie(Group_val[:3], labels = Group_names[:3], autopct = '%1.2f%%')
# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Group of Attackers', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Group with the most attacks is
#
# 1. Taliban
# 2. Islamic State of Iraq and the Levant (ISIL)

# %%
Attacks_types = terrorism.AttackType.value_counts().index
Atttack_types_num = terrorism.AttackType.value_counts().values

# %%
plt.pie(Atttack_types_num[:3], labels = Attacks_types[:3], autopct = '%1.2f%%')
# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')
plt.title('Top 3 Types of Attacks', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# We get to know that the Most Types of Attacks are
#
# 1. Bombing/Explosion
# 2. Armed Assault
# 3. Assassination

# %% [markdown]
# **Visualizing the data**

# %%
plt.figure(figsize = (15, 6))
sns.countplot(x = 'Year', data = terrorism)
plt.xticks(rotation = 90)
plt.title('Number Of Terrorist Activities Each Year', fontname = 'serif', fontsize = 16)
plt.show()

# %%
pd.crosstab(terrorism.Year, terrorism.Region).plot(kind = 'area', figsize = (15, 6))
plt.ylabel('Number of Attacks', fontname = 'serif', fontsize = 14)
plt.title('Terrorist Activities by Region in each Year', fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# From this graph we can say that
#
# 1. Number of attacks in Middle East & North Africa and South Asia increased after year 2010
# 2. Number of attacks in Central America & Carribbean and South America decreased after 1990
# 3. Eastern

# %%
# Set the figure size
plt.figure(figsize = (15, 6))
sns.barplot(x = terrorism['Country'].value_counts()[:20].index, y = terrorism['Country'].value_counts()[:20].values)
plt.xlabel('Countries', fontname = 'serif', fontsize = 14)
plt.ylabel('Count', fontname = 'serif', fontsize = 14)
plt.title('Top Countries Affected by Terrorism', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The top 5 countries affected by terrorism are
#
# 1. Iran
# 2. Pakistan
# 3. Afghanistan
# 4. India
# 5. Columbia

# %%
KillData = terrorism.loc[:, 'Killed']
KillData = KillData.dropna()
Total_Kill = int(sum(KillData))
print(Total_Kill)
# Out:
# 411868

# %% [markdown]
# The total number of people killed by Terror Attacks is 411868

# %%
grouped_data = terrorism.groupby('AttackType')['Killed'].sum().reset_index()
typeKillFormatData = grouped_data.pivot_table( columns = 'AttackType', values = 'Killed', aggfunc = 'sum')
typeKillFormatData
# Out:
# AttackType  Armed Assault  Assassination  Bombing/Explosion  \
# Killed           160297.0        24920.0           157321.0
#
# AttackType  Facility/Infrastructure Attack  Hijacking  \
# Killed                              3642.0     3718.0
#
# AttackType  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# Killed                                   4478.0                      24231.0
#
# AttackType  Unarmed Assault  Unknown
# Killed                880.0  32381.0

# %%
typeKillFormatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, Killed to Killed
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Armed Assault                        1 non-null      float64
#  1   Assassination                        1 non-null      float64
#  2   Bombing/Explosion                    1 non-null      float64
#  3   Facility/Infrastructure Attack       1 non-null      float64
#  4   Hijacking                            1 non-null      float64
#  5   Hostage Taking (Barricade Incident)  1 non-null      float64
#  6   Hostage Taking (Kidnapping)          1 non-null      float64
#  7   Unarmed Assault                      1 non-null      float64
#  8   Unknown                              1 non-null      float64
# dtypes: float64(9)
# memory usage: 80.0+ bytes

# %%
sum_killed = typeKillFormatData.sum()

# Get labels and values for the pie chart
labels = sum_killed.index.tolist()
values = sum_killed.values.tolist()

# Create a pie chart
plt.figure(figsize = (10, 10))
plt.pie(values, labels = labels, autopct = '%.2f%%')
plt.title('Types of terrorist attacks that cause deaths', fontname = 'serif', fontsize = 14)
# Location of the legend
plt.legend()
# An equal aspect ratio ensures a circular pie chart
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
38.20 + 38.92
# Out:
# 77.12

# %% [markdown]
# Upto 77% of the deaths are the result of Armed assault and bombing/explosion

# %%
yr_kill = terrorism[['Year', 'Killed']].groupby("Year").sum().reset_index()
yr_kill.head()
# Out:
#    Year  Killed
# 0  1970   174.0
# 1  1971   173.0
# 2  1972   566.0
# 3  1973   370.0
# 4  1974   539.0

# %%
max_killed_year = yr_kill.loc[yr_kill['Killed'].idxmax()]
max_killed_year
# Out:
# Year       2014.0
# Killed    44490.0
# Name: 43, dtype: float64

# %%
yr_wounded = terrorism[['Year', 'Wounded']].groupby("Year").sum().reset_index()
yr_wounded.head()
# Out:
#    Year  Wounded
# 0  1970    212.0
# 1  1971     82.0
# 2  1972    409.0
# 3  1973    495.0
# 4  1974    865.0

# %%
max_wounded_year = yr_wounded.loc[yr_wounded['Wounded'].idxmax()]
max_wounded_year
# Out:
# Year        2015.0
# Wounded    44043.0
# Name: 44, dtype: float64

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = 'Year', y = 'Killed', data = yr_kill, palette = 'viridis')
plt.xlabel('Year', fontname = 'serif', fontsize = 14)
plt.ylabel('Total Killed', fontname = 'serif', fontsize = 14)
plt.title('Total Killed by Year', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Maximum Kill were occureed in 2014 and Minimin in 1971

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = 'Year', y = 'Wounded', data = yr_wounded, palette = 'viridis')
plt.xlabel('Year', fontname = 'serif', fontsize = 14)
plt.ylabel('Total Wounded', fontname = 'serif', fontsize = 14)
plt.title('Total Wounded by Year', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Maximum Wounded occurred in 2015 and Minimin in 1971

# %% [markdown]
# **Observation**
#
# **Year wise Attacks**
#
# **(i) Attack**
#
# (a) Most number of attacks were in 2014
#
# (b) The least number of attacks was in 1971
#
# **(ii) Killed**
#
# (a) The highest number of people killed was 44490 in 2014
#
# (b) The least number of people killed was 173 in 1971
#
# **(iii) Wounded**
#
# (a) Most number of people wounded was 44043 in 2015
#
# (b) The least number of people wounded was 82 in 1971

# %%
region = pd.crosstab(terrorism.Year, terrorism.Region)
region
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
# 1975                        0                            9             0
# 1976                        0                           45             0
# 1977                        0                           24             0
# 1978                        2                          199             0
# 1979                        2                          609             0
# 1980                        7                         1070             0
# 1981                        3                         1148             0
# ...

# %%
region_wounded = terrorism[['Region', 'Wounded']].groupby("Region").sum().reset_index()
region_wounded
# Out:
#                          Region   Wounded
# 0         Australasia & Oceania     260.0
# 1   Central America & Caribbean    8991.0
# 2                  Central Asia    2009.0
# 3                     East Asia    9213.0
# 4                Eastern Europe   12045.0
# 5    Middle East & North Africa  214308.0
# 6                 North America   21531.0
# 7                 South America   16704.0
# 8                    South Asia  141360.0
# 9                Southeast Asia   26259.0
# 10           Sub-Saharan Africa   52857.0
# 11               Western Europe   18332.0

# %%
region_kill = terrorism[['Region', 'Killed']].groupby("Region").sum().reset_index()
region_kill
# Out:
#                          Region    Killed
# 0         Australasia & Oceania     150.0
# 1   Central America & Caribbean   28708.0
# 2                  Central Asia    1000.0
# 3                     East Asia    1152.0
# 4                Eastern Europe    7415.0
# 5    Middle East & North Africa  137642.0
# 6                 North America    4916.0
# 7                 South America   28849.0
# 8                    South Asia  101319.0
# 9                Southeast Asia   15637.0
# 10           Sub-Saharan Africa   78386.0
# 11               Western Europe    6694.0

# %% [markdown]
# **Observation**
#
# **Region wise Attacks**
#
# **(i) Attack**
#
# (a) Most attacks were in "The Middle East & North Africa"
#
# (b) The least number of attacks were in "Australia & Oceania"
#
# **(ii) Killed**
#
# (a) Most number of people killed was 137642 in "Middle East & North Africa"
#
# (b) The least number of people killed was 410 in "Australia & Oceania"
#
# **(iii) Wounded**
#
# (a) The most number of people wounded was 214308 in "Middle East & North Africa"
#
# (b) The least number of people wounded was 260 in "Australia & Oceania"

# %%
Country_attack = terrorism['Country'].value_counts().head(10)
Country_attack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = Country_attack.index, y = Country_attack.values, palette = 'viridis')
plt.xlabel('Country', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Attacks', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Countries with the Most Attacks', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
Country_kill = terrorism[['Country','Killed']].groupby("Country").sum().sort_values(by = "Killed", ascending = False)
Country_kill.head(10)
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = Country_kill.index[:10], y = Country_kill['Killed'][:10], palette = 'viridis')
plt.xlabel('Country', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Kills', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Countries with the Most Kills', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
Country_wounded = terrorism[['Country','Wounded']].groupby("Country").sum().sort_values(by = "Wounded", ascending = False)
Country_wounded.head(10)
# Out:
#                 Wounded
# Country
# Iraq           134690.0
# Afghanistan     44277.0
# Pakistan        42038.0
# India           28980.0
# United States   20702.0
# Sri Lanka       15561.0
# Syria           14109.0
# Philippines     13367.0
# Lebanon         10904.0
# Colombia        10328.0

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = Country_wounded.index[:10], y = Country_wounded['Wounded'][:10], palette = 'viridis')
plt.xlabel('Country', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Wounded', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Countries with the Most Wounded', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Observation**
#
# **Countries wise Attacks**
#
# **(i) Attack**
#
# (a) Most numbers of attacks were 24636 in "Iraq"
#
# (b) Least number of attacks was 4292 in "Turkey"
#
# **(ii) Killed**
#
# (a) The most number of people killed was 78589 in "Iraq"
#
# (b) Least number of people killed was 12053 in "El Salvador"
#
# **(iii) Wounded**
#
# (a) The most number of people wounded was 134690 in "Iraq"
#
# (b) Least number of people wounded was 10328 in " Colombia"

# %%
City_attack = terrorism['city'].value_counts()[1:11]
City_attack
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: city, dtype: int64

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = City_attack.index, y = City_attack.values, palette = 'viridis')
plt.xlabel('city', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Attacks', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Cities with the Most Attacks', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
City_wounded = terrorism[['city', 'Wounded']].groupby("city").sum().sort_values(by = "Wounded", ascending = False)
City_wounded.head(10)
# Out:
#                Wounded
# city
# Baghdad        56725.0
# New York City  16781.0
# Unknown        12803.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = City_wounded.index[:10], y = Country_wounded['Wounded'][:10], palette = 'viridis')
plt.xlabel('City', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Wounded', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Cities with the Most Wounded', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
City_killed = terrorism[['city', 'Killed']].groupby("city").sum().sort_values(by = "Killed", ascending = False)
City_wounded.head(10)
# Out:
#                Wounded
# city
# Baghdad        56725.0
# New York City  16781.0
# Unknown        12803.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x = City_killed.index[:10], y = City_killed['Killed'][1:11], palette = 'viridis')
plt.xlabel('City', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Killed', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Cities with the Most Killed', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Observation**
#
# **Cities wise Attacks**
#
# **(i) Attack**
#
# (a) Most numbers of attacks were 7589 in "Baghdad"
#
# (b) Least number of attacks was 1019 in "Athens"
#
# **(ii) Killed**
#
# (a) The most number of people killed was 21151 in "Baghdad"
#
# (b) The least number of people killed was 2125 in "Aleppo"
#
# **(iii) Wounded**
#
# (a) Most numbers of people wounded were 56725 in "Baghdad"
#
# (b) The least number of people wounded was 4955 in " Mogadishu"

# %%
group_attack = terrorism['Group'].value_counts()[1:11]
group_attack
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: Group, dtype: int64

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = group_attack.index, y = group_attack.values, palette = 'viridis')
plt.xlabel('Group', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Attacks', fontname = 'serif', fontsize = 14)
plt.title('Top 10 Groups with  Most Attacks', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
group_wounded = terrorism[['Group','Wounded']].groupby("Group").sum().sort_values(by = "Wounded", ascending = False).drop("Unknown")
group_wounded.head(10)
# Out:
#                                              Wounded
# Group
# Islamic State of Iraq and the Levant (ISIL)  30672.0
# Taliban                                      27932.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      11031.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9532.0
# Boko Haram                                    9473.0
# Al-Shabaab                                    7624.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4908.0

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = group_wounded.index[:10], y = group_wounded['Wounded'][:10], palette = 'viridis')
plt.xlabel('Group', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Wounded', fontname = 'serif', fontsize = 14)
plt.title('Wounded by groups', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
group_killed = terrorism[['Group', 'Killed']].groupby("Group").sum().sort_values(by = "Killed", ascending = False).drop("Unknown")
group_killed.head(10)
# Out:
#                                                    Killed
# Group
# Islamic State of Iraq and the Levant (ISIL)       38923.0
# Taliban                                           29410.0
# Boko Haram                                        20328.0
# Shining Path (SL)                                 11601.0
# Liberation Tigers of Tamil Eelam (LTTE)           10989.0
# Al-Shabaab                                         9330.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6042.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x = group_killed.index[:10], y = group_killed['Killed'][:10], palette = 'viridis')
plt.xlabel('Group', fontname = 'serif', fontsize = 14)
plt.ylabel('Number of Killed', fontname = 'serif', fontsize = 14)
plt.title('Killed by groups', fontname = 'serif', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Observation**
#
# **Groups wise Attacks**
#
# **(i) Attack**
#
# (a) Most numbers of attacks were 7478 in "Taliban"
#
# (b) The least number of attacks was 2310 in "Kurdistan Workers' Party (PKK)"
#
# **(ii) Killed**
#
# (a) Most number of people killed was 38923 in "Islamic State of Iraq and the Levant (ISIL)"
#
# (b) The least number of people killed was 5661 in "Revolutionary Armed Forces of Colombia (FARC)"
#
# **(iii) Wounded**
#
# (a) Most number of people wounded was 30672 in "Islamic State of Iraq and the Levant (ISIL)"
#
# (b) The least number of people wounded was 4908 in "Kurdistan Workers' Party (PKK)"
